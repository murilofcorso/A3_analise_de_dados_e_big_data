# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import numpy as np

def million_formatter(x, pos):
    """Formatador para milhões"""
    return '%1.0fM' % (x * 1e-6)

def billion_formatter(x, pos):
    """Formatador para milhões"""
    return '%1.0fB' % (x * 1e-9)

#D92938
#03738C
#999B9A
#F2F2F2
#000000

# %%
pd.set_option('future.no_silent_downcasting', True)

regioes = pd.read_excel('base_consolidada.xlsx', sheet_name='regioes')  # SERASA 2026
inadimplentes = pd.read_excel('base_consolidada.xlsx', sheet_name='inadimplentes').replace('n.d.', np.nan)  # SERASA 2026
setores = pd.read_excel('base_consolidada.xlsx', sheet_name='setores').replace('n.d.', np.nan)  # SERASA 2026
urbanizacao = pd.read_excel('base_consolidada.xlsx', sheet_name='urbanizacao')  # IBGE 2010
custo_de_vida = pd.read_excel('base_consolidada.xlsx', sheet_name='custo_de_vida')  # https://tableaubrasil.com.br/financeiro/custo-de-vida-nos-estados-do-brasil
populacao_por_regiao = pd.read_excel('base_consolidada.xlsx', sheet_name='populacao_por_regiao')  # IBGE 2025
populacao_por_estado = pd.read_excel('base_consolidada.xlsx', sheet_name='populacao_por_estado')  # IBGE 2025


regioes_2026 = regioes[regioes.mes.dt.year == 2026].reset_index(drop=True).drop('mes', axis=1)[['regiao', 'estado', 'estado_sigla', 'consumidores_inadimplentes', 'dividas_negativadas', 'valor_dividas_negativadas', 'divida_media_por_cpf', 'valor_divida_media', 'ticket_medio', 'porcentagem_adultos']]
regioes_2026 = pd.merge(regioes_2026, populacao_por_estado, on='estado')
regioes_2026['proporcao_consumidores_inadimplentes'] = regioes_2026['consumidores_inadimplentes'] / regioes_2026['populacao']
proporcao_inadimplencia = regioes_2026.sort_values('proporcao_consumidores_inadimplentes', ascending=False)[['estado', 'proporcao_consumidores_inadimplentes']]

# %%
plot = inadimplentes[['mes', 'consumidores_inadimplentes_MI', 'ate_25_anos', 'entre_26_e_40_anos', 'entre_41_e_60_anos', 'acima_60_anos']].copy()
plot['ate_25_anos'] = plot['ate_25_anos'] / plot['consumidores_inadimplentes_MI']
plot['entre_26_e_40_anos'] = plot['entre_26_e_40_anos'] / plot['consumidores_inadimplentes_MI']
plot['entre_41_e_60_anos'] = plot['entre_41_e_60_anos'] / plot['consumidores_inadimplentes_MI']
plot['acima_60_anos'] = plot['acima_60_anos'] / plot['consumidores_inadimplentes_MI']

fig, ax = plt.subplots(figsize=(10, 6))

# inadimplência por faixa etária
sns.lineplot(plot, x='mes', y='ate_25_anos', label='Até 25 anos', ax=ax)
sns.lineplot(plot, x='mes', y='entre_26_e_40_anos', label='Entre 26 e 40 anos', ax=ax)
sns.lineplot(plot, x='mes', y='entre_41_e_60_anos', label='Entre 41 e 60 anos', ax=ax)
sns.lineplot(plot, x='mes', y='acima_60_anos', label='Acima de 60 anos', ax=ax)
ax.yaxis.set_major_formatter(ticker.PercentFormatter(1))
ax.set_title('Inadimplencia Por Faixa Etária (%)')
ax.set_ylabel('')
ax.set_xlabel('')
ax.grid(lw=.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Através da análise por faixa etária percebe-se que:</h3>
# <ul style="font-size: 16px;">
#     <li>A maioria dos endividados tem entre 26 e 60 anos</li>
#     <li>Entre os anos de 2019 e 2026, a taxa de inadimplência tem diminuido entre os mais jovens e aumentado entre os mais velhos.</li>
#     <li>O maior aumento na taxa de inadimplentes esteve entre o público maior de 60 anos, representando um crescimento de 4,7% entre 2019 e 2026</li>
#     <li>Indicativo de dificuldade no quitamento das dívidas</li>
# </ul>

# %% [markdown]
# <h1>Tipos de dívidas e financeirização do crédito</h1>
# <!-- A financeirização do crédito é o processo onde a lógica dos mercados financeiros domina a concessão de empréstimos, transformando dívidas em ativos negociáveis (securitização) e priorizando o lucro financeiro sobre a função social do crédito. Esse fenômeno aumenta o endividamento das famílias e empresas, tornando-as dependentes de mecanismos financeiros. -->
# <ul style="font-size: 16px;">
#     <li>Crescimento da participação do mercado financeiro na concessão de créditos</li>
#     <li>Priorização do lucro sobre a função social do crédito</li>
# </ul>

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 6))
plot = setores[['mes', 'total_financeiro_AF', 'total_nao_financeiro_BCDEGHI']].copy()
plot['ano'] = plot.mes.dt.year
plot = plot.groupby('ano')[['total_financeiro_AF', 'total_nao_financeiro_BCDEGHI']].mean()
axes[0].pie(plot.loc[2019], labels=['Financeiro', 'Não financeiro'], autopct='%1.1f%%', colors=['#D92938', '#03738C'])
axes[0].set_title('Participação de capitais na inadimplência (2019)')
axes[1].pie(plot.loc[2026], labels=['Financeiro', 'Não financeiro'], autopct='%1.1f%%', colors=['#D92938', '#03738C'])
axes[1].set_title('Participação de capitais na inadimplência (2026)')
plt.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))

sns.lineplot(setores[['mes', 'financeiras_F']][setores.mes.dt.year >= 2019], x='mes', y='financeiras_F', ax=ax, color='#D92938')
ax.yaxis.set_major_formatter(ticker.PercentFormatter(1))
ax.set_title('Participação De Instituições Financeiras Na Inadimplência Total (%)'.title())
ax.set_ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Respondendo as questões levantadas</h1>

# %% [markdown]
# <h3>1. A maior oferta e facilidade do crédito digital em áreas urbanas aumentam o uso impulsivo, elevando a taxa de endividamento?</h3>
# <h3>2. Regiões com maior custo de vida exigem mais gastos, levando jovens a recorrerem ao crédito e se endividarem?</h3>
# <h3>3. Jovens com pouco conhecimento financeiro tendem a usar crédito sem planejamento, acumulando dívidas?</h3>

# %%
top_6_urbanizados = urbanizacao.iloc[0:6, 0:2]

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(
    proporcao_inadimplencia, 
    y='estado', 
    x='proporcao_consumidores_inadimplentes', 
    orient='h', 
    ax=ax,
    color='#03738C'
)
sns.barplot(
    proporcao_inadimplencia[proporcao_inadimplencia.estado.isin(top_6_urbanizados.estado.values)], 
    y='estado', 
    x='proporcao_consumidores_inadimplentes', 
    orient='h', 
    ax=ax,
    color='#D92938',
    label='Top 6 estados com maior taxa de urbanização'
)
ax.xaxis.set_major_formatter(ticker.PercentFormatter(1))
ax.set_title('Taxa De Inadimplência Por Estado (%)')
ax.set_ylabel('')
ax.set_xlabel('Taxa de inadimplência')
ax.set_xlim(xmin=proporcao_inadimplencia.proporcao_consumidores_inadimplentes.min() - 0.01)
ax.annotate('Os 5 estados mais inadimplentes do Brasil estão entre os 6\nmais urbanizados do país.', (0.385, 12))
ax.annotate('Distrito Federal, Rio de Janeiro e São Paulo estão entre os 4\nestados com maior custo de vida, ficando abaixo apenas\ndo Paraná', (0.385, 15.5))
plt.show()

# %% [markdown]
# <ul>
#     <li>Apesar do Paraná ser o estado brasileiro com o maior custo de vida e ser consideravelmente urbanizado, sua taxa de inadimplência não é tão elevada quanto a dos seus semelhantes.</li>
#     <li>No Paraná, a educação financeira foi integrada na grade curricular do ensino médio desde 2021</li>
#     <li>No Acre, políticas de renegociação de dívidas, campanhas de conscientização financeira e a ação contundente do Instituto de Proteção e Defesa do Consumidor do Acre, tem apresentado resultados, sendo o estado com a terceira menor inadimplência do país (32,3% da população inadimplente)</li>
# </ul>
# <!-- https://revistas.pucsp.br/index.php/emd/article/view/65730 -->
# <!-- https://agencia.ac.gov.br/investimento-em-educacao-financeira-resultam-em-destaque-para-o-acre-com-a-menor-inadimplencia-do-norte/ -->

# %%
# streamlit

# %%
regioes_2026
# Out:
#           regiao               estado estado_sigla  \
# 0          Norte                 Acre           AC
# 1       Nordeste              Alagoas           AL
# 2          Norte                Amapá           AP
# 3          Norte             Amazonas           AM
# 4       Nordeste                Bahia           BA
# 5       Nordeste                Ceará           CE
# 6   Centro-Oeste     Distrito Federal           DF
# 7        Sudeste       Espírito Santo           ES
# 8   Centro-Oeste                Goiás           GO
# 9       Nordeste             Maranhão           MA
# 10  Centro-Oeste          Mato Grosso           MT
# 11  Centro-Oeste   Mato Grosso do Sul           MS
# 12       Sudeste         Minas Gerais           MG
# 13         Norte                 Pará           PA
# 14      Nordeste              Paraíba           PB
# 15           Sul               Paraná           PR
# 16      Nordeste           Pernambuco           PE
# ...
